# %% [markdown]
# ## Movie Recommendation System

# %% [markdown]
# ### 1. Dataset
# The movie dataset comes from [MovieLens](https://grouplens.org/datasets/movielens/latest/). This dataset describes 5-star rating and free-text tagging activity from MovieLens, a movie recommendation service.

# %%
import pandas as pd
import numpy as np

# %%
#import data
df=pd.read_csv('movies.csv')
df_tag=pd.read_csv('tags.csv')
df_rating=pd.read_csv('ratings.csv')

# %%
df.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
df_tag.head()
# Out:
#    userId  movieId           tag   timestamp
# 0      14      110          epic  1443148538
# 1      14      110      Medieval  1443148532
# 2      14      260        sci-fi  1442169410
# 3      14      260  space action  1442169421
# 4      14      318  imdb top 250  1442615195

# %%
df_rating.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1      307     3.5  1256677221
# 1       1      481     3.5  1256677456
# 2       1     1091     1.5  1256677471
# 3       1     1257     4.5  1256677460
# 4       1     1449     4.5  1256677264

# %%
def parse_movie_genres(genres):
    return genres.split('|')

# %%
df['categories']=df['genres'].apply(parse_movie_genres)

# %%
df.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres  \
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy
#
#                                           categories
# 0  [Adventure, Animation, Children, Comedy, Fantasy]
# 1                     [Adventure, Children, Fantasy]
# 2                                  [Comedy, Romance]
# 3                           [Comedy, Drama, Romance]
# 4                                           [Comedy]

# %% [markdown]
# ### 2. Feature Engineering

# %% [markdown]
# Since the genre is a categorical variable,one-hot encoding should be used, which gives each genre its own dimension in feature space.Here I use [DictVectorizer](https://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.DictVectorizer.html
# ). This transformer turns lists of mappings (dict-like objects) of feature names to feature values into Numpy arrays or spare matrics for use with scikit-learn estimators.
#
# Before using DictVectorizer, the column genre should be in dict-like format.

# %%
from sklearn import base
class DictEncoder(base.BaseEstimator, base.TransformerMixin):
    
    def __init__(self, col):
        self.col = col
    
    def fit(self, X, y=None):
        return self
    
    def transform(self, X):
        
        def to_dict(l):
            try:
                return {x: 1 for x in l}
            except TypeError:
                return {}
        
        return X[self.col].apply(to_dict)

# %%
a=DictEncoder('categories')
a.fit_transform(df)[:5]
# Out:
# 0    {'Adventure': 1, 'Animation': 1, 'Children': 1...
# 1        {'Adventure': 1, 'Children': 1, 'Fantasy': 1}
# 2                          {'Comedy': 1, 'Romance': 1}
# 3              {'Comedy': 1, 'Drama': 1, 'Romance': 1}
# 4                                        {'Comedy': 1}
# Name: categories, dtype: object

# %%
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction import DictVectorizer

pipe=Pipeline([('encoder', DictEncoder('categories')),\
              ('vectorizer', DictVectorizer())])

features=pipe.fit_transform(df)
features
# Out:
# <58098x20 sparse matrix of type '<class 'numpy.float64'>'
# 	with 106107 stored elements in Compressed Sparse Row format>

# %% [markdown]
# The DictVectorizer returns a sparse matrix, each row represents a movie, columns are the categories where if the movie has that category, the value is 1, otherwise 0.

# %% [markdown]
# ### 3. Model

# %% [markdown]
# Clearly, choosing similar movie uses feature similarity. So this is a [NearestNeighbors](https://scikit-learn.org/stable/modules/neighbors.html) problem.Sklearn.neighbors provides functionality for unsupervised and supervised neighbors-based learning methods.The principle behind nearest neighbor methods is to find a predefined number of training samples closet in distance to the new point. The distance can, in general, be any metric measure: standard Euclidean distance is the most common choice. Neighbors-based methods are known as non-generalizing and non-parametic machine learning methods, since they simply "remember" all of its training data, calculate the distances between the new point and the whole training data and find the closest n_neighbors points, where n_neighbors is a hyperparameter.

# %%
from sklearn.neighbors import NearestNeighbors

nn=NearestNeighbors(n_neighbors=20).fit(features)

# %% [markdown]
# Let's see what movies are similar to the first movie

# %%
df.iloc[0]
# Out:
# movieId                                                       1
# title                                          Toy Story (1995)
# genres              Adventure|Animation|Children|Comedy|Fantasy
# categories    [Adventure, Animation, Children, Comedy, Fantasy]
# Name: 0, dtype: object

# %%
#distance is array to show the distance from the closest 20 movies to <Toy Story> and indice is the array showing
#the locations of movies.
distance, indice=nn.kneighbors(features[0])
df.iloc[indice[0]]
# Out:
#        movieId                                              title  \
# 2210      2294                                        Antz (1998)
# 54888   186159                  Tangled: Before Ever After (2017)
# 25073   115879                  Toy Story Toons: Small Fry (2011)
# 25651   117454                           The Magic Crystal (2011)
# 32912   136361         Scooby-Doo! Mask of the Blue Falcon (2012)
# 0            1                                   Toy Story (1995)
# 11009    45074                                   Wild, The (2006)
# 32793   136016                           The Good Dinosaur (2015)
# 52769   181601                     Olaf's Frozen Adventure (2017)
# 50764   177037       Puss in Book: Trapped in an Epic Tale (2017)
# 45832   166461                                       Moana (2016)
# 10130    33463  DuckTales: The Movie - Treasure of the Lost La...
# 3923      4016                   Emperor's New Groove, The (2000)
# 21576   103755                                       Turbo (2013)
# 18403    91355  Asterix and the Vikings (Astérix et les Viking...
# 54897   186177                              Trolls Holiday (2017)
# 13378    65577                     Tale of Despereaux, The (2008)
# 25071   115875          Toy Story Toons: Hawaiian Vacation (2011)
# 30715   131248                              Brother Bear 2 (2006)
# 3028      3114                                 Toy Story 2 (1999)
#
#                                             genres  \
# 2210   Adventure|Animation|Children|Comedy|Fantasy
# 54888  Adventure|Animation|Children|Comedy|Fantasy
# 25073  Adventure|Animation|Children|Comedy|Fantasy
# 25651  Adventure|Animation|Children|Comedy|Fantasy
# 32912  Adventure|Animation|Children|Comedy|Fantasy
# 0      Adventure|Animation|Children|Comedy|Fantasy
# 11009  Adventure|Animation|Children|Comedy|Fantasy
# 32793  Adventure|Animation|Children|Comedy|Fantasy
# 52769  Adventure|Animation|Children|Comedy|Fantasy
# 50764  Adventure|Animation|Children|Comedy|Fantasy
# 45832  Adventure|Animation|Children|Comedy|Fantasy
# 10130  Adventure|Animation|Children|Comedy|Fantasy
# 3923   Adventure|Animation|Children|Comedy|Fantasy
# 21576  Adventure|Animation|Children|Comedy|Fantasy
# 18403  Adventure|Animation|Children|Comedy|Fantasy
# 54897  Adventure|Animation|Children|Comedy|Fantasy
# 13378  Adventure|Animation|Children|Comedy|Fantasy
# 25071  Adventure|Animation|Children|Comedy|Fantasy
# 30715  Adventure|Animation|Children|Comedy|Fantasy
# 3028   Adventure|Animation|Children|Comedy|Fantasy
#
#                                               categories
# 2210   [Adventure, Animation, Children, Comedy, Fantasy]
# 54888  [Adventure, Animation, Children, Comedy, Fantasy]
# 25073  [Adventure, Animation, Children, Comedy, Fantasy]
# 25651  [Adventure, Animation, Children, Comedy, Fantasy]
# 32912  [Adventure, Animation, Children, Comedy, Fantasy]
# 0      [Adventure, Animation, Children, Comedy, Fantasy]
# 11009  [Adventure, Animation, Children, Comedy, Fantasy]
# 32793  [Adventure, Animation, Children, Comedy, Fantasy]
# 52769  [Adventure, Animation, Children, Comedy, Fantasy]
# 50764  [Adventure, Animation, Children, Comedy, Fantasy]
# 45832  [Adventure, Animation, Children, Comedy, Fantasy]
# 10130  [Adventure, Animation, Children, Comedy, Fantasy]
# 3923   [Adventure, Animation, Children, Comedy, Fantasy]
# 21576  [Adventure, Animation, Children, Comedy, Fantasy]
# 18403  [Adventure, Animation, Children, Comedy, Fantasy]
# 54897  [Adventure, Animation, Children, Comedy, Fantasy]
# 13378  [Adventure, Animation, Children, Comedy, Fantasy]
# 25071  [Adventure, Animation, Children, Comedy, Fantasy]
# 30715  [Adventure, Animation, Children, Comedy, Fantasy]
# 3028   [Adventure, Animation, Children, Comedy, Fantasy]

# %% [markdown]
# The similar movies for Toy Story are reasonable. All of the movies have the exactly same categories.

# %% [markdown]
# ### 3. User Tag

# %% [markdown]
# Above I just use movie categories to find similar movies, but it is not specific to a user. Thus, this section I use tags created by users to identify movie recommendation.

# %%
#get all tags for each movie
tags=df_tag.groupby('movieId')['tag'].apply(lambda x: x.tolist())
tags=pd.DataFrame(tags).reset_index()

# %%
tags.head()
# Out:
#    movieId                                                tag
# 0        1  [animated, buddy movie, Cartoon, cgi, comedy, ...
# 1        2  [fantasy, adapted from:book, animals, bad cgi,...
# 2        3  [moldy, old, Ann Margaret, Burgess Meredith, D...
# 3        4  [characters, girl movie, characters, chick fli...
# 4        5  [steve martin, steve martin, pregnancy, remake...

# %%
#merge movie dataset with tags
df=df.merge(tags, how='left', left_on='movieId', right_on='movieId')

# %%
df.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres  \
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy
#
#                                           categories  \
# 0  [Adventure, Animation, Children, Comedy, Fantasy]
# 1                     [Adventure, Children, Fantasy]
# 2                                  [Comedy, Romance]
# 3                           [Comedy, Drama, Romance]
# 4                                           [Comedy]
#
#                                                  tag
# 0  [animated, buddy movie, Cartoon, cgi, comedy, ...
# 1  [fantasy, adapted from:book, animals, bad cgi,...
# 2  [moldy, old, Ann Margaret, Burgess Meredith, D...
# 3  [characters, girl movie, characters, chick fli...
# 4  [steve martin, steve martin, pregnancy, remake...

# %%
#one-hot encode tags
tag_pipe=Pipeline([('encoder', DictEncoder('tag')),\
               ('vectorizer', DictVectorizer())])

# %%
from sklearn.pipeline import FeatureUnion

union=FeatureUnion([('categories', pipe), \
                   ('tags', tag_pipe)])

# %%
df['tag']=df['tag'].astype(str)
df['categories']=df['categories'].astype(str)

# %%
df.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres  \
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy
#
#                                           categories  \
# 0  ['Adventure', 'Animation', 'Children', 'Comedy...
# 1               ['Adventure', 'Children', 'Fantasy']
# 2                              ['Comedy', 'Romance']
# 3                     ['Comedy', 'Drama', 'Romance']
# 4                                         ['Comedy']
#
#                                                  tag
# 0  ['animated', 'buddy movie', 'Cartoon', 'cgi', ...
# 1  ['fantasy', 'adapted from:book', 'animals', 'b...
# 2  ['moldy', 'old', 'Ann Margaret', 'Burgess Mere...
# 3  ['characters', 'girl movie', 'characters', 'ch...
# 4  ['steve martin', 'steve martin', 'pregnancy', ...

# %%
features=union.fit_transform(df)
features
# Out:
# <58098x407 sparse matrix of type '<class 'numpy.float64'>'
# 	with 1955658 stored elements in Compressed Sparse Row format>

# %%
nn=NearestNeighbors(n_neighbors=20).fit(features)

# %%
df.iloc[0]
# Out:
# movieId                                                       1
# title                                          Toy Story (1995)
# genres              Adventure|Animation|Children|Comedy|Fantasy
# categories    ['Adventure', 'Animation', 'Children', 'Comedy...
# tag           ['animated', 'buddy movie', 'Cartoon', 'cgi', ...
# Name: 0, dtype: object

# %%
distance, indice=nn.kneighbors(features[0])
df.iloc[indice[0]]
# Out:
#        movieId                                              title  \
# 0            1                                   Toy Story (1995)
# 3028      3114                                 Toy Story 2 (1999)
# 32293   134853                                  Inside Out (2015)
# 13345    65261                 Ponyo (Gake no ue no Ponyo) (2008)
# 1113      1136             Monty Python and the Holy Grail (1975)
# 4791      4886                              Monsters, Inc. (2001)
# 4212      4306                                       Shrek (2001)
# 13812    68954                                          Up (2009)
# 3309      3396                           Muppet Movie, The (1979)
# 5520      5618  Spirited Away (Sen to Chihiro no kamikakushi) ...
# 6430      6539  Pirates of the Caribbean: The Curse of the Bla...
# 11516    49649                                      Eragon (2006)
# 4801      4896  Harry Potter and the Sorcerer's Stone (a.k.a. ...
# 17128    86298                                         Rio (2011)
# 8278      8961                            Incredibles, The (2004)
# 1824      1907                                       Mulan (1998)
# 11183    46948                               Monster House (2006)
# 14475    72226                           Fantastic Mr. Fox (2009)
# 39494   152081                                    Zootopia (2016)
# 6272      6377                                Finding Nemo (2003)
#
#                                                   genres  \
# 0            Adventure|Animation|Children|Comedy|Fantasy
# 3028         Adventure|Animation|Children|Comedy|Fantasy
# 32293  Adventure|Animation|Children|Comedy|Drama|Fantasy
# 13345               Adventure|Animation|Children|Fantasy
# 1113                            Adventure|Comedy|Fantasy
# 4791         Adventure|Animation|Children|Comedy|Fantasy
# 4212   Adventure|Animation|Children|Comedy|Fantasy|Ro...
# 13812                 Adventure|Animation|Children|Drama
# 3309                   Adventure|Children|Comedy|Musical
# 5520                         Adventure|Animation|Fantasy
# 6430                     Action|Adventure|Comedy|Fantasy
# 11516                           Action|Adventure|Fantasy
# 4801                          Adventure|Children|Fantasy
# 17128                Adventure|Animation|Children|Comedy
# 8278          Action|Adventure|Animation|Children|Comedy
# 1824   Adventure|Animation|Children|Comedy|Drama|Musi...
# 11183                 Animation|Children|Fantasy|Mystery
# 14475          Adventure|Animation|Children|Comedy|Crime
# 39494         Action|Adventure|Animation|Children|Comedy
# 6272                 Adventure|Animation|Children|Comedy
#
#                                               categories  \
# 0      ['Adventure', 'Animation', 'Children', 'Comedy...
# 3028   ['Adventure', 'Animation', 'Children', 'Comedy...
# 32293  ['Adventure', 'Animation', 'Children', 'Comedy...
# 13345  ['Adventure', 'Animation', 'Children', 'Fantasy']
# 1113                  ['Adventure', 'Comedy', 'Fantasy']
# 4791   ['Adventure', 'Animation', 'Children', 'Comedy...
# 4212   ['Adventure', 'Animation', 'Children', 'Comedy...
# 13812    ['Adventure', 'Animation', 'Children', 'Drama']
# 3309      ['Adventure', 'Children', 'Comedy', 'Musical']
# 5520               ['Adventure', 'Animation', 'Fantasy']
# 6430        ['Action', 'Adventure', 'Comedy', 'Fantasy']
# 11516                 ['Action', 'Adventure', 'Fantasy']
# 4801                ['Adventure', 'Children', 'Fantasy']
# 17128   ['Adventure', 'Animation', 'Children', 'Comedy']
# 8278   ['Action', 'Adventure', 'Animation', 'Children...
# 1824   ['Adventure', 'Animation', 'Children', 'Comedy...
# 11183    ['Animation', 'Children', 'Fantasy', 'Mystery']
# 14475  ['Adventure', 'Animation', 'Children', 'Comedy...
# 39494  ['Action', 'Adventure', 'Animation', 'Children...
# 6272    ['Adventure', 'Animation', 'Children', 'Comedy']
#
#                                                      tag
# 0      ['animated', 'buddy movie', 'Cartoon', 'cgi', ...
# 3028   ['Pixar', 'sequel better than original', 'aban...
# 32293  ['imaginative', 'psychology', 'creative', 'emo...
# 13345  ['environmental', 'environmentalism', 'friends...
# 1113   ['british comedy', 'excellent dialogue', 'High...
# 4791   ['funny', 'Pixar', 'Comedy', 'funny', 'Pixar',...
# 4212   ['fairy tale', 'Funny', 'Kids', 'animation', '...
# 13812  ['adventure', 'Pixar', 'bittersweet', 'romance...
# 3309   ['funny', 'Jim Henson', 'Kermit the Frog', 'mu...
# 5520   ['want to own', 'alternate reality', 'atmosphe...
# 6430   ['Slashy', 'adventure', 'fantasy', 'romance', ...
# 11516  ['Jeremy Irons', 'fantasy', 'dragons', 'based ...
# 4801   ['school drama', 'based on a book', 'based on ...
# 17128  ['comedy', 'cute animation', 'funny', 'made me...
# 8278   ['funny', 'stylized', 'super-hero', 'animation...
# 1824   ['Disney', 'Eddie Murphy', 'feminism', 'femini...
# 11183  ['animation', 'claymation', 'halloween', 'haun...
# 14475  ['based on a book', 'great cast', 'hilarious',...
# 39494  ['acceptance', 'cute', 'police', 'racism', 'so...
# 6272   ['Pixar', 'funny', 'Pixar', 'family', 'father-...

# %% [markdown]
# With Users' tags,*Toy story 2* is the most similar movie now.However, another issue comes up.Clearly *Pirates of the Caribbean* and *Eragon* are not very related to *Toy Story*.

# %% [markdown]
# ### 3. Dimension Reduction

# %% [markdown]
# Dimension reduction is very important when there are a lot of features which could cause overfitting and increase computational cost.Here I am going to use [TruncatedSVD](https://scikit-learn.org/stable/modules/generated/sklearn.decomposition.TruncatedSVD.html).This transformer performs linear dimensionality reduction by means of truncated singular value decomposition.Contrary to PCA, this estimator does not center the data before computing the singular value decomposition, which means it can work with sparse matrices efficiently.

# %%
from sklearn.decomposition import TruncatedSVD

svd=TruncatedSVD(n_components=100)
tag_pipe=Pipeline([('encoder', DictEncoder('tag')),
                     ('vectorizer', DictVectorizer()),
                     ('svd', svd)])
union=FeatureUnion([('categories', pipe), \
                   ('tags', tag_pipe)])

# %%
features=union.fit_transform(df)
features
# Out:
# <58098x138 sparse matrix of type '<class 'numpy.float64'>'
# 	with 6583658 stored elements in Compressed Sparse Row format>

# %%
nn=NearestNeighbors(n_neighbors=20).fit(features)

# %%
distance, indice=nn.kneighbors(features[5])
df.iloc[indice[0]]
# Out:
#        movieId                            title  \
# 5            6                      Heat (1995)
# 4760      4855               Dirty Harry (1971)
# 1017      1036                  Die Hard (1988)
# 26547   120466                   Chappie (2015)
# 6765      6874         Kill Bill: Vol. 1 (2003)
# 7313      7438         Kill Bill: Vol. 2 (2004)
# 4117      4210                 Manhunter (1986)
# 2874      2959                Fight Club (1999)
# 2204      2288                Thing, The (1982)
# 14333    71535                Zombieland (2009)
# 8115      8798                Collateral (2004)
# 12519    58295             Bank Job, The (2008)
# 2487      2571               Matrix, The (1999)
# 1870      1953    French Connection, The (1971)
# 345        349  Clear and Present Danger (1994)
# 27545   122882        Mad Max: Fury Road (2015)
# 285        288      Natural Born Killers (1994)
# 20249    98961          Zero Dark Thirty (2012)
# 6115      6213          Tears of the Sun (2003)
# 1232      1260                         M (1931)
#
#                                    genres  \
# 5                   Action|Crime|Thriller
# 4760                Action|Crime|Thriller
# 1017                Action|Crime|Thriller
# 26547                     Action|Thriller
# 6765                Action|Crime|Thriller
# 7313                Action|Drama|Thriller
# 4117   Action|Crime|Drama|Horror|Thriller
# 2874          Action|Crime|Drama|Thriller
# 2204        Action|Horror|Sci-Fi|Thriller
# 14333                Action|Comedy|Horror
# 8115          Action|Crime|Drama|Thriller
# 12519               Action|Crime|Thriller
# 2487               Action|Sci-Fi|Thriller
# 1870                Action|Crime|Thriller
# 345           Action|Crime|Drama|Thriller
# 27545    Action|Adventure|Sci-Fi|Thriller
# 285                 Action|Crime|Thriller
# 20249               Action|Drama|Thriller
# 6115                Action|Drama|Thriller
# 1232             Crime|Film-Noir|Thriller
#
#                                               categories  \
# 5                        ['Action', 'Crime', 'Thriller']
# 4760                     ['Action', 'Crime', 'Thriller']
# 1017                     ['Action', 'Crime', 'Thriller']
# 26547                             ['Action', 'Thriller']
# 6765                     ['Action', 'Crime', 'Thriller']
# 7313                     ['Action', 'Drama', 'Thriller']
# 4117   ['Action', 'Crime', 'Drama', 'Horror', 'Thrill...
# 2874            ['Action', 'Crime', 'Drama', 'Thriller']
# 2204          ['Action', 'Horror', 'Sci-Fi', 'Thriller']
# 14333                     ['Action', 'Comedy', 'Horror']
# 8115            ['Action', 'Crime', 'Drama', 'Thriller']
# 12519                    ['Action', 'Crime', 'Thriller']
# 2487                    ['Action', 'Sci-Fi', 'Thriller']
# 1870                     ['Action', 'Crime', 'Thriller']
# 345             ['Action', 'Crime', 'Drama', 'Thriller']
# 27545      ['Action', 'Adventure', 'Sci-Fi', 'Thriller']
# 285                      ['Action', 'Crime', 'Thriller']
# 20249                    ['Action', 'Drama', 'Thriller']
# 6115                     ['Action', 'Drama', 'Thriller']
# 1232                  ['Crime', 'Film-Noir', 'Thriller']
#
#                                                      tag
# 5      ['overrated', 'bank robbery', 'crime', 'heists...
# 4760   ['Andrew Robinson', 'Clint Eastwood', 'Lalo Sc...
# 1017   ['action', 'Alan Rickman', 'thriller', 'violen...
# 26547  ['AI', 'artificial intelligence', 'cyberpunk',...
# 6765   ['Kick-Butt Women', 'martial arts', 'nonlinear...
# 7313   ['martial arts', 'mystery writer', 'samurai', ...
# 4117   ['Acting', 'atmospheric', 'based on a book', '...
# 2874   ['ohsoso', 'Brad Pitt', 'Brad Pitt', 'dark com...
# 2204   ['aliens', 'paranoia', 'shape shifter', 'claus...
# 14333  ['clever', 'dark comedy', 'Jesse Eisenberg', '...
# 8115   ['NOT AS GOOD AS HEAT', 'action', 'drama', 'ab...
# 12519  ['obscene', 'ClearPlay', 'R', '1970s', 'based ...
# 2487   ['the one', 'ohsoso', 'action', 'alternate rea...
# 1870   ['Action', 'car chase', 'cops', 'Gene Hackman'...
# 345    ['Action Scenes', 'Harrison Ford', 'CIA', 'men...
# 27545  ['beautiful', 'believable', 'dystopian', 'non-...
# 285    ['Robert Downey Jr', 'dark comedy', 'psychedel...
# 20249  ['assassination', 'boring to death', 'complex ...
# 6115   ['Monica Bellucci', 'military', 'Antoine Fuqua...
# 1232   ['atmospheric', 'black and white', 'child kill...

# %% [markdown]
# ### 4. Movie Recommendation

# %% [markdown]
# When a user logs into a movie website, movies recommended to the user should be not just based on movie catogeries but also user's historical perference.Here the approach is to average movies previously watched and rated by the user. First, select all movies watched and rated by the user and find the corresponding features. Second, use these movies' rating scores to weight the features to find the "average" movie. Last, use nearestneighbors algorithm to find the most silimar movies to the "average" movie.

# %%
#merge rating with movie data
df_rating_movie=df_rating.merge(df, how='left', left_on='movieId', right_on='movieId')
df_rating_movie=df_rating_movie[['userId', 'movieId', 'rating', 'title', 'categories', 'tag']]

# %% [markdown]
# We look at userId==5, and see what the user like to watch.

# %%
def select_movies(userId):
    """
    select movies according to userId.
    Args: userId (int)
    Returns: dataframe
    """
    return df_rating_movie[df_rating_movie['userId']==userId].sort_values('rating', ascending=False)

# %%
#look at userId==5, and see what the user like to watch.
userId=5
userId5=select_movies(userId)
userId5
# Out:
#      userId  movieId  rating  \
# 791       5     1222     5.0
# 790       5     1213     5.0
# 810       5     5995     5.0
# 811       5     6016     5.0
# 813       5     7361     5.0
# 779       5       50     5.0
# 798       5     2858     5.0
# 826       5    44195     5.0
# 829       5    46976     5.0
# 793       5     1732     5.0
# 805       5     4973     5.0
# 804       5     4226     5.0
# 785       5      778     5.0
# 844       5    55247     5.0
# 782       5      318     5.0
# 781       5      296     5.0
# 848       5    56367     5.0
# 833       5    48774     4.5
# 837       5    50068     4.5
# 831       5    48516     4.5
# 839       5    52952     4.5
# 842       5    54997     4.5
# 822       5    32587     4.5
# 817       5     8950     4.5
# 847       5    55820     4.5
# 807       5     5137     4.5
# 814       5     8784     4.5
# 849       5    56782     4.5
# 787       5     1147     4.5
# 786       5      858     4.5
# ..      ...      ...     ...
# 835       5    49272     4.0
# 834       5    48780     4.0
# 789       5     1193     4.0
# 832       5    48696     4.0
# 846       5    55765     4.0
# 830       5    48394     4.0
# 806       5     5110     4.0
# 778       5       47     4.0
# 825       5    40278     4.0
# 818       5    27831     4.0
# 809       5     5954     4.0
# 802       5     3949     4.0
# 801       5     3178     4.0
# 815       5     8873     4.0
# 797       5     2502     4.0
# 816       5     8949     4.0
# 819       5    30749     4.0
# 820       5    30820     4.0
# 821       5    31410     4.0
# 823       5    33794     4.0
# 824       5    38061     4.0
# 794       5     2060     3.5
# 800       5     3173     3.5
# 812       5     6322     3.5
# 808       5     5528     3.5
# 780       5      293     3.5
# 828       5    46578     3.5
# 796       5     2485     3.0
# 784       5      728     3.0
# 788       5     1186     2.0
#
#                                                  title  \
# 791                           Full Metal Jacket (1987)
# 790                                  Goodfellas (1990)
# 810                                Pianist, The (2002)
# 811                City of God (Cidade de Deus) (2002)
# 813       Eternal Sunshine of the Spotless Mind (2004)
# 779                         Usual Suspects, The (1995)
# 798                             American Beauty (1999)
# 826                       Thank You for Smoking (2006)
# 829                       Stranger than Fiction (2006)
# 793                           Big Lebowski, The (1998)
# 805  Amelie (Fabuleux destin d'Amélie Poulain, Le) ...
# 804                                     Memento (2000)
# 785                               Trainspotting (1996)
# 844                               Into the Wild (2007)
# 782                   Shawshank Redemption, The (1994)
# 781                                Pulp Fiction (1994)
# 848                                        Juno (2007)
# 833                             Children of Men (2006)
# 837                       Letters from Iwo Jima (2006)
# 831                               Departed, The (2006)
# 839                             This Is England (2006)
# 842                                3:10 to Yuma (2007)
# 822                                    Sin City (2005)
# 817                               The Machinist (2004)
# 847                      No Country for Old Men (2007)
# 807                                     Scratch (2001)
# 814                                Garden State (2004)
# 849                         There Will Be Blood (2007)
# 787                          When We Were Kings (1996)
# 786                              Godfather, The (1972)
# ..                                                 ...
# 835                               Casino Royale (2006)
# 834                               Prestige, The (2006)
# 789             One Flew Over the Cuckoo's Nest (1975)
# 832                             Little Children (2006)
# 846                           American Gangster (2007)
# 830   Pan's Labyrinth (Laberinto del fauno, El) (2006)
# 806                              Super Troopers (2001)
# 778                        Seven (a.k.a. Se7en) (1995)
# 825                                     Jarhead (2005)
# 818                                  Layer Cake (2004)
# 809                                   25th Hour (2002)
# 802                         Requiem for a Dream (2000)
# 801                              Hurricane, The (1999)
# 815  Motorcycle Diaries, The (Diarios de motociclet...
# 797                                Office Space (1999)
# 816                                    Sideways (2004)
# 819                                Hotel Rwanda (2004)
# 820                               Woodsman, The (2004)
# 821                   Downfall (Untergang, Der) (2004)
# 823                               Batman Begins (2005)
# 824                         Kiss Kiss Bang Bang (2005)
# 794                                 BASEketball (1998)
# 800                            Any Given Sunday (1999)
# 812                                  Confidence (2003)
# 808                              One Hour Photo (2002)
# 780  Léon: The Professional (a.k.a. The Professiona...
# 828                        Little Miss Sunshine (2006)
# 796                              She's All That (1999)
# 784                           Cold Comfort Farm (1995)
# 788                    Sex, Lies, and Videotape (1989)
#
#                                             categories  \
# 791                                   ['Drama', 'War']
# 790                                 ['Crime', 'Drama']
# 810                                   ['Drama', 'War']
# 811  ['Action', 'Adventure', 'Crime', 'Drama', 'Thr...
# 813                     ['Drama', 'Romance', 'Sci-Fi']
# 779                   ['Crime', 'Mystery', 'Thriller']
# 798                               ['Drama', 'Romance']
# 826                                ['Comedy', 'Drama']
# 829          ['Comedy', 'Drama', 'Fantasy', 'Romance']
# 793                                ['Comedy', 'Crime']
# 805                              ['Comedy', 'Romance']
# 804                            ['Mystery', 'Thriller']
# 785                       ['Comedy', 'Crime', 'Drama']
# 844                   ['Action', 'Adventure', 'Drama']
# 782                                 ['Crime', 'Drama']
# 781           ['Comedy', 'Crime', 'Drama', 'Thriller']
# 848                     ['Comedy', 'Drama', 'Romance']
# 833  ['Action', 'Adventure', 'Drama', 'Sci-Fi', 'Th...
# 837                                   ['Drama', 'War']
# 831                     ['Crime', 'Drama', 'Thriller']
# 839                                          ['Drama']
# 842            ['Action', 'Crime', 'Drama', 'Western']
# 822  ['Action', 'Crime', 'Film-Noir', 'Mystery', 'T...
# 817                   ['Drama', 'Mystery', 'Thriller']
# 847                                 ['Crime', 'Drama']
# 807                                    ['Documentary']
# 814                     ['Comedy', 'Drama', 'Romance']
# 849                               ['Drama', 'Western']
# 787                                    ['Documentary']
# 786                                 ['Crime', 'Drama']
# ..                                                 ...
# 835                ['Action', 'Adventure', 'Thriller']
# 834         ['Drama', 'Mystery', 'Sci-Fi', 'Thriller']
# 789                                          ['Drama']
# 832                               ['Drama', 'Romance']
# 846                     ['Crime', 'Drama', 'Thriller']
# 830                   ['Drama', 'Fantasy', 'Thriller']
# 806                     ['Comedy', 'Crime', 'Mystery']
# 778                            ['Mystery', 'Thriller']
# 825                         ['Action', 'Drama', 'War']
# 818                     ['Crime', 'Drama', 'Thriller']
# 809                                 ['Crime', 'Drama']
# 802                                          ['Drama']
# 801                                          ['Drama']
# 815                             ['Adventure', 'Drama']
# 797                                ['Comedy', 'Crime']
# 816                     ['Comedy', 'Drama', 'Romance']
# 819                                   ['Drama', 'War']
# 820                                          ['Drama']
# 821                                   ['Drama', 'War']
# 823                        ['Action', 'Crime', 'IMAX']
# 824         ['Comedy', 'Crime', 'Mystery', 'Thriller']
# 794                                         ['Comedy']
# 800                                          ['Drama']
# 812                              ['Crime', 'Thriller']
# 808                              ['Drama', 'Thriller']
# 780           ['Action', 'Crime', 'Drama', 'Thriller']
# 828                   ['Adventure', 'Comedy', 'Drama']
# 796                              ['Comedy', 'Romance']
# 784                                         ['Comedy']
# 788                                          ['Drama']
#
#                                                    tag
# 791  ['Stanley Kubrick', 'political', 'drill instru...
# 790  ['crime', 'dark comedy', 'disturbing', 'gangst...
# 810  ['holocaust', 'Nazis', 'World War II', 'dramat...
# 811  ['Brazil', 'crime', 'drugs', 'killing', 'money...
# 813  ['bittersweet', 'Charlie Kaufman', 'Elijah Woo...
# 779  ['great acting', 'storytelling', 'twist ending...
# 798  ['adultery', 'loneliness', 'midlife crisis', '...
# 826  ['Adam Brody', 'corporate greed', 'satire', 'c...
# 829  ['modern fantasy', 'metaphysics', 'modern fant...
# 793  ['black comedy', 'Coen Brothers', 'Jeff Bridge...
# 805  ['ohsoso', 'a little boring', 'but still worth...
# 804  ['backwards', 'memory', 'memory loss', 'nonlin...
# 785  ['addiction', 'British', 'cult film', 'drug', ...
# 844  ['Alaska', 'atmospheric', 'road trip', 'self d...
# 782  ['imdb top 250', 'justice', 'story line', 'hop...
# 781  ['Tarantino', 'funny', 'overrated', 'pulp', 'c...
# 848  ['comedy', 'high school', 'pregnancy', 'quirky...
# 833  ['apocalypse', 'atmospheric', 'bleak', 'depres...
# 837  ['Got', 'Clint Eastwood', 'Deep', 'japanese', ...
# 831  ['atmospheric', 'complicated plot', 'gangsters...
# 839  ['coming of age', 'England', 'original skinhea...
# 842  ['Ben Foster', 'Christian Bale', 'father-son r...
# 822  ['stylized', 'black comedy', 'brutality', 'can...
# 817  ['Christian Bale', 'imaginary friend', 'Overra...
# 847  ['a movie about death', 'lack of character dev...
# 807  ['hip hop', 'music documentary', 'own', 'Doug ...
# 814  ['atmospheric', 'friendship', 'Great Soundtrac...
# 849  ['Daniel Day-Lewis', 'father-son relationship'...
# 787  ['vibrant', 'boxing', 'Muhammad Ali', 'boxing'...
# 786  ['classic', 'dvd', 'boring', 'italian mafia', ...
# ..                                                 ...
# 835  ['James Bond', 'James Bond', 'bittersweet', 'g...
# 834  ['atmospheric', 'Christian Bale', 'complicated...
# 789  ['ohsoso', 'jack nicholson', 'drama', 'emotion...
# 832  ['Nudity (Topless - Notable)', 'reflective', '...
# 846  ['Chiwetel Ejiofor', 'corruption', 'Denzel Was...
# 830  ['disturbing', 'imagination', 'gore', 'surreal...
# 806  ['comedy', 'degrading', 'drugs', 'marijuana', ...
# 778  ['David Fincher', 'disturbing', 'philosophical...
# 825  ['History', 'iraq', 'Jake Gyllenhaal', 'Jamie ...
# 818  ['drugs', 'guy ritchie', 'british', 'British c...
# 809  ['philip seymour hoffman', 'powerful ending', ...
# 802  ['ohsoso', 'depressing', 'disturbing', 'intens...
# 801  ['John Hannah', 'inspirational', 'inspirationa...
# 815  ['Che Guevara', 'road trip', 'adventure', 'bea...
# 797  ['satire', 'cult film', 'dark comedy', 'satire...
# 816  ['Black Humor At Its Best', 'mid-life crisis',...
# 819  ['Africa', 'history', 'killing', 'Rwanda', 'Un...
# 820  ['Disturbing and moving', 'paedophilia', 'chil...
# 821  ['end of war', 'in the bunker', 'Berlin', 'Ger...
# 823  ['superheros', 'Christian Bale', 'dark', 'styl...
# 824  ['Slashy', 'get', 'Robert Downey Jr', 'absurd'...
# 794  ['Trey Parker', 'dumb', 'Matt Stone', 'slightl...
# 800  ['Pacino', 'bad movie', 'braindead', 'flawed',...
# 812  ['twist ending', 'corruption', 'on dvr', 'redh...
# 808  ['not that good', 'Robin Williams at his best....
# 780  ['assassin', 'organized crime', 'great acting'...
# 828  ['good fun', 'Greg Kinnear', 'dark comedy', 's...
# 796  ['okay', "now it's a little dumb.", 'Watched m...
# 784  ['1930s', 'based on a book', 'Classism', 'Engl...
# 788  ['breakthroughs', 'sundance movie', 'Golden Pa...
#
# [72 rows x 6 columns]

# %% [markdown]
# looks like userId==5' favarite movies are in crime and drama categories.

# %%
#normalize rating scale in [0, 1]
scale=select_movies(userId)['rating']*0.2

# %%
#from movieId find the index and then
index=select_movies(userId)['movieId'].apply(lambda x: df.index[df['movieId']==x]).tolist()

flatten_index=[x for y in index for x in y]

# %%
weighted_avg_movie = scale.values.reshape(1,-1).dot(features[flatten_index,:].toarray()) / len(scale)

# %%
distance, indice=nn.kneighbors(weighted_avg_movie)

# %%
df.iloc[indice[0]]
# Out:
#        movieId                                           title  \
# 10309    34437                           Broken Flowers (2005)
# 1057      1079                     Fish Called Wanda, A (1988)
# 5368      5464                        Road to Perdition (2002)
# 1178      1203                             12 Angry Men (1957)
# 3061      3147                          Green Mile, The (1999)
# 9587     30749                             Hotel Rwanda (2004)
# 3231      3317                              Wonder Boys (2000)
# 7447      7748                           Pierrot le fou (1965)
# 12246    55820                   No Country for Old Men (2007)
# 1149      1172  Cinema Paradiso (Nuovo cinema Paradiso) (1989)
# 4681      4776                             Training Day (2001)
# 2646      2731  400 Blows, The (Les quatre cents coups) (1959)
# 3066      3152                   Last Picture Show, The (1971)
# 7497      7820       Virgin Spring, The (Jungfrukällan) (1960)
# 1862      1945                        On the Waterfront (1954)
# 43621   161582                       Hell or High Water (2016)
# 2245      2329                       American History X (1998)
# 1429      1466                            Donnie Brasco (1997)
# 10603    40583                                  Syriana (2005)
# 3110      3196                                Stalag 17 (1953)
#
#                      genres                      categories  \
# 10309          Comedy|Drama             ['Comedy', 'Drama']
# 1057           Comedy|Crime             ['Comedy', 'Crime']
# 5368            Crime|Drama              ['Crime', 'Drama']
# 1178                  Drama                       ['Drama']
# 3061            Crime|Drama              ['Crime', 'Drama']
# 9587              Drama|War                ['Drama', 'War']
# 3231           Comedy|Drama             ['Comedy', 'Drama']
# 7447            Crime|Drama              ['Crime', 'Drama']
# 12246           Crime|Drama              ['Crime', 'Drama']
# 1149                  Drama                       ['Drama']
# 4681   Crime|Drama|Thriller  ['Crime', 'Drama', 'Thriller']
# 2646            Crime|Drama              ['Crime', 'Drama']
# 3066                  Drama                       ['Drama']
# 7497            Crime|Drama              ['Crime', 'Drama']
# 1862            Crime|Drama              ['Crime', 'Drama']
# 43621           Crime|Drama              ['Crime', 'Drama']
# 2245            Crime|Drama              ['Crime', 'Drama']
# 1429            Crime|Drama              ['Crime', 'Drama']
# 10603        Drama|Thriller           ['Drama', 'Thriller']
# 3110              Drama|War                ['Drama', 'War']
#
#                                                      tag
# 10309  ['almost no plot', 'Bill Murray', 'mediocre pl...
# 1057   ['absurd', 'black comedy', 'British', 'dark co...
# 5368   ['father and son', 'organized crime', 'Oscar b...
# 1178   ['thought-provoking', 'classic', 'social comme...
# 3061   ['Stephen King', 'Tom Hanks', 'compassionate',...
# 9587   ['Africa', 'history', 'killing', 'Rwanda', 'Un...
# 3231   ['college', 'Gay', 'literature', 'Michael Doug...
# 7447   ['Jean-Paul Belmondo', 'Anna Karina', 'french ...
# 12246  ['a movie about death', 'lack of character dev...
# 1149   ['bittersweet', 'Giuseppe Tornatore', 'superb ...
# 4681   ['denzel washington', 'Ethan Hawke', 'Oscar (B...
# 2646   ['youth', 'emotional', 'gentle', 'heartwarming...
# 3066   ['period piece', 'Oscar (Best Supporting Actor...
# 7497   ['medieval', 'religion', 'faith', 'medieval', ...
# 1862   ['Marlon Brando', 'Marlon Brando', 'Oscar (Bes...
# 43621  ['Ben Foster', 'cinematography', 'dialogue', '...
# 2245   ['Edward Norton', 'thought-provoking', 'confro...
# 1429   ['mentor', 'based on a true story', 'Mafia', '...
# 10603  ['complex', 'complicated', 'espionage', 'Matt ...
# 3110   ['tenacity', 'Oscar (Best Actor)', 'Netflix DV...

# %% [markdown]
# Above 20 movies recommended to userId==5 seem like reasonable.
